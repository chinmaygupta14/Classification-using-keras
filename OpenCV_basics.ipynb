# %% [markdown]
# <a href="https://colab.research.google.com/github/chinmaygupta14/Classification-using-keras/blob/master/OpenCV_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Matplotlib and PIL

# %%
from google.colab import drive

# %matplotlib inline
# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# Using PIL for the image
# https:/pillow.readthedocs.io/en/stable/reference/Image.html

# %%
from PIL import Image

# %%
img=Image.open("/content/drive/My Drive/opencvv.jpg")

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img_arr=np.asarray(img)

# %%
img_arr.shape
# Out:
# (1408, 672, 3)

# %%
plt.imshow(img_arr)

# %%
img_test=img_arr.copy()

# %%
plt.imshow(img_test[:,:, 0])

# %%
img=cv2.imread("/content/drive/My Drive/opencvv.jpg")

# %%
img

# %%
type(img)
# Out:
# NoneType

# %%
img.shape

# %%
plt.imshow(img)

# %%
img_fix=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_fix)

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

# %%
def draw_circle(event,x,y,flags,param):
  if event==cv2.EVENT_LBUTTONDOWN:
    cv.circle(img,(x,y),70,(35,69,78), -1)

cv2.namedWindow(winname='my_drawing')

cv2.setMouseCallback('my_drawing', draw_circle)

img=np.zeros((512,512,3),np.int8)

while True:
  cv2.imshow('my_drawing',img)

  if cv2.waitKey(5) & 0xFF==27:
    break

cv2.destroyAllWindows()
